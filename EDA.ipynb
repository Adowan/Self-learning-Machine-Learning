# %%
import pandas as pd
pd.set_option('display.max_columns',None)
data = pd.read_csv('employees.csv')
data
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team  Unnamed: 8  Unnamed: 9  \
# 0                True             Marketing         NaN         NaN
# ...

# %%
data.shape
# Out:
# (1000, 15)

# %%
data_1 = data.drop(['Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'], axis=1)

# %%
data_1.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
data_1['Start Date']= pd.to_datetime(data_1['Start Date'])

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
## lets see how many percentage are null values
round( (data_1.isnull().sum()/ data_1.shape[0])*100, 2)
# Out:
# First Name            6.7
# Gender               14.5
# Start Date            0.0
# Last Login Time       0.0
# Salary                0.0
# Bonus %               0.0
# Senior Management     6.7
# Team                  4.3
# dtype: float64

# %%
data_1.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      720
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64

# %%
#lets fill the missing values of gender with no gender
data_1['Gender'].fillna("No Gender", inplace= True)
round((data_1.isnull().sum()/ data_1.shape[0])*100,2)
# Out:
# First Name           6.7
# Gender               0.0
# Start Date           0.0
# Last Login Time      0.0
# Salary               0.0
# Bonus %              0.0
# Senior Management    6.7
# Team                 4.3
# dtype: float64

# %%
data_1
# Out:
#     First Name     Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas       Male 1996-03-31         6:53 AM   61933    4.170
# 2        Maria     Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry       Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry       Male 1998-01-24         4:47 PM  101004    1.389
# ..         ...        ...        ...             ...     ...      ...
# 995      Henry  No Gender 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip       Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell       Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry       Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert       Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
# Now filling the null values with mode
import numpy as np
mode= data_1[ 'Senior Management'].mode().values[0]
data_1['Senior Management']= data_1['Senior Management'].replace(np.nan, mode)

# %%
round((data_1.isnull().sum()/ data_1.shape[0])*100,2)
# Out:
# First Name           6.7
# Gender               0.0
# Start Date           0.0
# Last Login Time      0.0
# Salary               0.0
# Bonus %              0.0
# Senior Management    0.0
# Team                 4.3
# dtype: float64

# %%
data_1 = data_1.dropna(axis=0, how='any')
print(round((data_1.isnull().sum()/ data_1.shape[0])*100,2))
print('\n Now the dimensions are:',data_1.shape)
# Out:
# First Name           0.0
# Gender               0.0
# Start Date           0.0
# Last Login Time      0.0
# Salary               0.0
# Bonus %              0.0
# Senior Management    0.0
# Team                 0.0
# dtype: float64
#
#  Now the dimensions are: (899, 8)

# %% [markdown]
# ## Encoding for Categorical Values

# %%
## Using pandas
enc_pan= pd.get_dummies(data_1, columns=['Gender'])
enc_pan
# Out:
#     First Name Start Date Last Login Time  Salary  Bonus %  Senior Management  \
# 0      Douglas 1993-08-06        12:42 PM   97308    6.945               True
# 2        Maria 1993-04-23        11:17 AM  130590   11.858              False
# 3        Jerry 2005-03-04         1:00 PM  138705    9.340               True
# 4        Larry 1998-01-24         4:47 PM  101004    1.389               True
# 5       Dennis 1987-04-18         1:35 AM  115163   10.125              False
# ..         ...        ...             ...     ...      ...                ...
# 995      Henry 2014-11-23         6:09 AM  132483   16.655              False
# 996    Phillip 1984-01-31         6:30 AM   42392   19.675              False
# 997    Russell 2013-05-20        12:39 PM   96914    1.421              False
# 998      Larry 2013-04-20         4:45 PM   60500   11.985              False
# 999     Albert 2012-05-15         6:24 PM  129949   10.169               True
#
# ...

# %%
## Using Scikit Learn
#from sklearn.preprocessing import OneHotEncoder

data_1['Gender'] = data_1['Gender'].astype('category')

data_1['Gender_new'] = data_1['Gender'].cat.codes

enc= OneHotEncoder()

enc_sk = pd.DataFrame( enc.fit_transform(data_1[['Gender']]).toarray())

new_enc=data_1.join(enc_sk)
#pd.set_option('display.max_rows',None)
new_enc.head(10)
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 2       Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3       Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4       Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 5      Dennis    Male 1987-04-18         1:35 AM  115163   10.125
# 6        Ruby  Female 1987-08-17         4:20 PM   65476   10.012
# 8      Angela  Female 2005-11-22         6:29 AM   95570   18.523
# 9     Frances  Female 2002-08-08         6:51 AM  139852    7.524
# 11      Julie  Female 1997-10-26         3:19 PM  102508   12.637
# 12    Brandon    Male 1980-12-01         1:08 AM  112807   17.492
#
#     Senior Management                  Team  Gender_new    0    1    2
# 0                True             Marketing           1  0.0  1.0  0.0
# 2               False               Finance           0  0.0  1.0  0.0
# ...

# %%
## Label Variable
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
data_1['Gender']= le.fit_transform(data_1['Gender']) 
data_1
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4876\2709165957.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_1['Gender']= le.fit_transform(data_1['Gender'])
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       1 1993-08-06        12:42 PM   97308    6.945
# 2        Maria       0 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry       1 2005-03-04         1:00 PM  138705    9.340
# 4        Larry       1 1998-01-24         4:47 PM  101004    1.389
# 5       Dennis       1 1987-04-18         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry       2 2014-11-23         6:09 AM  132483   16.655
# ...

# %% [markdown]
# ## Visualization - Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(  x= 'Salary',data = data_1)
plt.show()

# %%
Salary_sub= data_1[['Salary']]
Salary_sub.hist( bins= 11, figsize=(10,5))
plt.xlabel("Salary Amount")
plt.title('Histogram of Salary', fontdict={ 'fontweight':'bold'})
plt.show()

# %% [markdown]
# This proves that seaborn's outlook is better somehow

# %%
sns.boxplot( x='Salary', y='Team', data= data_1)
plt.figure(figsize=(10,5), dpi= 300)
plt.show()

# %%
sns.set_style('darkgrid')
sns.scatterplot( x= 'Salary', y='Team', data= data_1, hue='Gender', size='Bonus %', palette='deep')
plt.legend(bbox_to_anchor=(1,1),loc=2)
plt.figure(figsize=(16,9), dpi= 300)
plt.show()

# %%
sns.set_style('darkgrid')
sns.pairplot(data= data_1,hue='Gender',height=2,palette='deep')
plt.show()
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
otl= pd.read_csv('train.csv')
sns.boxplot( x= 'Age', data= otl)
plt.show()

# %%
# Import libraries
df= pd.read_csv('train.csv')
 
q1 = np.percentile(df['Fare'], 25, interpolation ='midpoint')
q3 = np.percentile(df['Fare'],75, interpolation ='midpoint')

print("This is value:",q3)
print("Q1 value:",q1)
IQR = q3-q1
print('Old shape:', df.shape)

upper= np.where(df['Fare'] >= (q3))
lower = np.where(df['Fare'] <= (q1))
 

df.drop( upper[0], inplace = True)
df.drop( lower[0], inplace = True)

print('New Shape:', df.shape)
sns.boxplot(x='Fare', data=df)
plt.show()
# Out:
# This is value: 31.0
# Q1 value: 7.9104
# Old shape: (891, 12)
# New Shape: (443, 12)
# C:\Users\USER\AppData\Local\Temp\ipykernel_4876\2629976382.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   q1 = np.percentile(df['Fare'], 25, interpolation ='midpoint')
# C:\Users\USER\AppData\Local\Temp\ipykernel_4876\2629976382.py:5: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   q3 = np.percentile(df['Fare'],75, interpolation ='midpoint')
